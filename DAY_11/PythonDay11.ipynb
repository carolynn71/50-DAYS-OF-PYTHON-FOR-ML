# %% [markdown]
# <a href="https://colab.research.google.com/github/carolynn71/50-DAYS-OF-PYTHON-FOR-ML/blob/main/DAY_11/PythonDay11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A `for` loop in Python is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string) or other iterable objects. Iterating over a sequence is called traversal.
#
# The basic syntax of a `for` loop is:
#
# ```python
# for item in iterable:
#     # code to execute for each item
# ```
#
# - `item`: This is a variable that takes on the value of the next item in the `iterable` during each iteration.
# - `iterable`: This can be any Python object that can be iterated over, such as a list, tuple, string, dictionary, or range object.
#
# The loop continues until all items in the `iterable` have been processed.

# %%
# Example of a for loop with a list
fruits = ["apple", "banana", "cherry"]
print("Iterating through a list of fruits:")
for fruit in fruits:
    print(fruit)

print("\nIterating through a string:")
# Example of a for loop with a string
word = "Python"
for char in word:
    print(char)

print("\nIterating through a range:")
# Example of a for loop with the range() function
for i in range(5): # range(5) generates numbers from 0 to 4
    print(i)

print("\nIterating through a dictionary (keys):")
# Example of a for loop with a dictionary (iterates over keys by default)
dictionary = {"name": "Alice", "age": 30}
for key in dictionary:
    print(f"{key}: {dictionary[key]}")
# Out:
# Iterating through a list of fruits:
# apple
# banana
# cherry
#
# Iterating through a string:
# P
# y
# t
# h
# o
# n
#
# Iterating through a range:
# 0
# 1
# 2
# 3
# 4
#
# Iterating through a dictionary (keys):
# name: Alice
# age: 30
