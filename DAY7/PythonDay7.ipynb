# %% [markdown]
# <a href="https://colab.research.google.com/github/carolynn71/50-DAYS-OF-PYTHON-FOR-ML/blob/main/DAY7/PythonDay7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## If-Else Statements: Theory and Code
#
# **If-else statements** are fundamental control flow structures in programming. They allow your code to make decisions and execute different blocks of code based on whether a certain condition is true or false.
#
# ### How they work:
#
# 1.  **`if` statement**: The code inside the `if` block is executed only if the condition specified is `True`.
# 2.  **`else` statement**: If the `if` condition is `False`, the code inside the `else` block is executed. An `else` statement is optional.
# 3.  **`elif` (else if) statement**: You can include one or more `elif` statements between `if` and `else` to check additional conditions if the preceding `if` or `elif` conditions were `False`.
#
# ### Syntax (Python):
#
# ```python
# if condition1:
#     # Code to execute if condition1 is True
# elif condition2:
#     # Code to execute if condition1 is False and condition2 is True
# else:
#     # Code to execute if all preceding conditions are False
# ```
#
# Conditions are typically expressions that evaluate to a boolean value (`True` or `False`), often using comparison operators (`==`, `!=`, `<`, `>`, `<=`, `>=`) and logical operators (`and`, `or`, `not`).

# %%
# Example of if-else statements

score = 85

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")

# Another example: checking if a number is even or odd

number = 7

if number % 2 == 0:
    print(f"The number {number} is even.")
else:
    print(f"The number {number} is odd.")
# Out:
# Grade: B
# The number 7 is odd.
