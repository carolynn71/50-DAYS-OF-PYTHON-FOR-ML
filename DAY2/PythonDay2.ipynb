# %% [markdown]
# <a href="https://colab.research.google.com/github/carolynn71/50-DAYS-OF-PYTHON/blob/main/DAY2/PythonDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DAY2

# %%
#COMMENTS

# %%
#comments:- A piece of code which is not executable by the compiler or interpetor

# %%
#comments are used for understandability for other coders or documentation

# %%
#-----> comment

# %%
#VARIABLES

# %%
#variable is a container used to store a value

# %%
name='sneha'
print(name)
#you dont need to declare the datatype of a variable
# Out:
# sneha

# %%
#name of variable= assignment
#NO VARIABLE DECLARATION

# %%
#DYNAMIC TYPING AND STATIC TYPING
#can change the varialbe to different types-->dynamic
#always the same datatype-->static

# %%
#SPECIAL_SYNTAX

# %%
a=5;b=6;c=7;
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a,b,c=4,5,6;
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a=b=c=7;
print(a)
print(b)
print(c)
# Out:
# 7
# 7
# 7
